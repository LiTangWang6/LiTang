# %%
import pyreadstat
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"]#设置字体

# %%
df = pd.read_spss(R'data\identity.sav')

# %%
#无序类别变量的描述统计
df['政治面貌'].value_counts(normalize=True)
# Out:
# 政治面貌
# 团员    0.734104
# 党员    0.130636
# 群众    0.110983
# 其他    0.024277
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
import mytools
import pandas as pd
from pyreadstat import pyreadstat
贵州茅台原始数据 = pd.read_csv(R'data/600519.csv')

# %%
import matplotlib.pyplot as plt 
result = 贵州茅台原始数据 = pd.read_csv(R'data/600519.csv').value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%') 
# 显示图形  99
plt.show()

# %%
#生成x.y轴方向的坐标
x = df['政治面貌'].value_counts().index
y = df['政治面貌'].value_counts(normalize=True).values * 100
# 创建图
fig, ax = plt.subplots()
# 绘制柱状图
rects1 = ax.bar(x,y)
# 设置x轴变量名称
ax.set_xlabel('政治面貌')
# 设置y轴最大值
ax.set_ylim(ymax=100)
# 在柱上方显示对应的值
ax.bar_label(rects1,fmt="%.1f",padding=3)
# 显示图形
plt.show()
