# %%
import pandas as pd
pd.read_csv(R'C:\Users\李华\Desktop\LiTang1\data\类别变量练习数据.csv',encoding = 'GBK',)
# Out:
#               父亲工作  Unnamed: 1  Unnamed: 2  Unnamed: 3 父亲职业重新编码  Unnamed: 5  \
# 0     中铁六局太原铁路建设公司         NaN         NaN         NaN       国企         NaN
# 1       凯信会议服务有限公司         NaN         NaN         NaN       民企         NaN
# 2       银光聚银化工有限公司         NaN         NaN         NaN       国企         NaN
# 3       元拓科技咨询有限公司         NaN         NaN         NaN       民企         NaN
# 4          市广播电视大学         NaN         NaN         NaN     事业单位         NaN
# 5         市经济合作局\n         NaN         NaN         NaN      公务员         NaN
# 6          区建豪汽修中心         NaN         NaN         NaN       个体         NaN
# 7          区建豪汽修中心         NaN         NaN         NaN       个体         NaN
# 8     陕西省水利水电第三工程局         NaN         NaN         NaN       国企         NaN
# 9   渭源陇原恒新畜牧科技有限公司         NaN         NaN         NaN       民企         NaN
# 10            市民政局         NaN         NaN         NaN      公务员         NaN
# ...

# %%
import mytools

# %%
父母职业相关性的描述分析 = pd.read_csv(R'C:\Users\李华\Desktop\LiTang1\类别变量练习数据.csv', encoding='GBK',)
tau_y = mytools.goodmanKruska_tau_y(父母职业相关性的描述分析,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.19671923886341627

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '极弱相关或无相关'

# %%
mytools.制作交叉表(父母职业相关性的描述分析,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企        个体      事业单位       公务员   国企      家庭主妇        民企  \
# 父亲职业重新编码
# 个体         0.0  0.500000  0.000000  0.000000  0.0  0.250000  0.142857
# 事业单位       0.0  0.000000  0.222222  0.000000  0.0  0.000000  0.000000
# 公务员        0.0  0.166667  0.666667  0.733333  0.5  0.000000  0.428571
# 国企         0.0  0.166667  0.000000  0.000000  0.5  0.166667  0.142857
# 家庭主妇       0.0  0.000000  0.000000  0.066667  0.0  0.166667  0.000000
# 民企         1.0  0.166667  0.111111  0.200000  0.0  0.416667  0.285714
#
# 母亲职业重新编码       All
# 父亲职业重新编码
# 个体        0.134615
# 事业单位      0.038462
# 公务员       0.423077
# 国企        0.096154
# 家庭主妇      0.057692
# 民企        0.250000

# %%
#绘制饼图
import matplotlib.pyplot as plt 
result = 父母职业相关性的描述分析['父亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%') 
 
# 显示图形  99
plt.show()

# %%
#绘制饼图
import matplotlib.pyplot as plt 
result = 父母职业相关性的描述分析['母亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%') 
 
# 显示图形  99
plt.show()
